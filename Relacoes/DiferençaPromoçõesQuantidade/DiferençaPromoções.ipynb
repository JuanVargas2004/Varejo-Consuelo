# %%
import pandas as pd
from scipy import stats

# Carregar os dados
df = pd.read_csv("DiferençaPromoçõesPython.csv", sep=";", encoding='latin1')

display(df)
# Out:
#      Produto  Dias_Promo  Volumes_Promo  Dias_SemPromo  Volumes_SemPromo  \
# 0          1           6             31            231              1201
# 1          2          10             35            226              1203
# 2          3           4             23            238              1279
# 3          4           4             15            260              1376
# 4          5           6             36            264              1471
# ..       ...         ...            ...            ...               ...
# 598      993           6             35            265              1511
# 599      994           2             18            271              1450
# 600      997          13             64            281              1487
# 601      998           4             23            252              1423
# 602      999           1              4            274              1505
#
#       Diferença
# 0     0,9937552
# 1    0,65752286
# 2    1,06997654
# 3    0,70857558
# 4    1,07681849
# ..          ...
# 598  1,02305317
# 599  1,68206897
# 600  0,93031918
# 601  1,01827126
# 602   0,7282392
#
# [603 rows x 6 columns]

# %%
# Calcular a média e desvio padrão dos volumes
mean_volumes_promo = df['Volumes_Promo'] / df['Dias_Promo']
mean_volumes_sempromo = df['Volumes_SemPromo'] / df['Dias_SemPromo']

# Realizar o teste t
t_stat, p_value = stats.ttest_ind(mean_volumes_promo, mean_volumes_sempromo)

print(f"T-statistic: {t_stat}")
print(f"P-value: {p_value}")
# Out:
# T-statistic: -0.9818489504625452
# P-value: 0.32637152024096383
